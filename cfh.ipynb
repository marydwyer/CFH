# %%
import pandas as pd
import numpy as np
from sklearn import gaussian_process
from sklearn import linear_model
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn import datasets
from sklearn import svm

np.set_printoptions(suppress=True)

# %%
#import data set 
trainingData = pd.read_csv('cfh.csv', index_col=0)
#print(trainingData.head())

# %% [markdown]
# # One-hot
# Replace categorical variables with numerical values. Use one-hot so one category does not weigh more than another.
# Before learning about ScikitLearn's one-hot encorder, I made individual numpy vectors for each possible case for a category.

# %%
#Replace data with numerical classifiers

#DOES THE CLIENT HAVE A HISTORY OF HOMELESSNESS
temp = trainingData['DOES THE CLIENT HAVE A HISTORY OF HOMELESSNESS']
temp.replace('Yes',value=1,inplace=True)
temp.replace('No',0,inplace=True)
A1 = temp

temp = trainingData['DOES THE CLIENT HAVE A HISTORY OF HOMELESSNESS']
temp.replace('Yes',value=0,inplace=True)
temp.replace('No',1,inplace=True)
A2 = temp

#GENDER HUD
temp = trainingData['GENDER HUD']
temp.replace('Female',value=1,inplace=True)
temp.replace('Male',0,inplace=True)
B1 = temp

temp = trainingData['GENDER HUD']
temp.replace('Female',value=0,inplace=True)
temp.replace('Male',1,inplace=True)
B2 = temp

#RACE CHECK ALL THAT APPLY_NCI
temp = trainingData['RACE CHECK ALL THAT APPLY_NCI']
temp.replace('American Indian or Alaskan Native', value=1,inplace=True)
temp.replace('Asian', 0,inplace=True)
temp.replace('Black or African-American', 0,inplace=True)
temp.replace('Hispanic/Latino', 0,inplace=True)
temp.replace('Native Hawaiian or other Pacific Islander', 0,inplace=True)
temp.replace('Asian', 0,inplace=True)
temp.replace('Other', 0,inplace=True)
temp.replace('White', 0,inplace=True)
C1 = temp

temp = trainingData['RACE CHECK ALL THAT APPLY_NCI']
temp.replace('American Indian or Alaskan Native', value=0,inplace=True)
temp.replace('Asian', 1,inplace=True)
temp.replace('Black or African-American', 0,inplace=True)
temp.replace('Hispanic/Latino', 0,inplace=True)
temp.replace('Native Hawaiian or other Pacific Islander', 0,inplace=True)
temp.replace('Asian', 0,inplace=True)
temp.replace('Other', 0,inplace=True)
temp.replace('White', 0,inplace=True)
C2 = temp

temp = trainingData['RACE CHECK ALL THAT APPLY_NCI']
temp.replace('American Indian or Alaskan Native', value=0,inplace=True)
temp.replace('Asian', 0,inplace=True)
temp.replace('Black or African-American', 1,inplace=True)
temp.replace('Hispanic/Latino', 0,inplace=True)
temp.replace('Native Hawaiian or other Pacific Islander', 0,inplace=True)
temp.replace('Asian', 0,inplace=True)
temp.replace('Other', 0,inplace=True)
temp.replace('White', 0,inplace=True)
C3 = temp

temp = trainingData['RACE CHECK ALL THAT APPLY_NCI']
temp.replace('American Indian or Alaskan Native', value=0,inplace=True)
temp.replace('Asian', 0,inplace=True)
temp.replace('Black or African-American', 0,inplace=True)
temp.replace('Hispanic/Latino', 1,inplace=True)
temp.replace('Native Hawaiian or other Pacific Islander', 0,inplace=True)
temp.replace('Asian', 0,inplace=True)
temp.replace('Other', 0,inplace=True)
temp.replace('White', 0,inplace=True)
C4 = temp

temp = trainingData['RACE CHECK ALL THAT APPLY_NCI']
temp.replace('American Indian or Alaskan Native', value=0,inplace=True)
temp.replace('Asian', 0,inplace=True)
temp.replace('Black or African-American', 0,inplace=True)
temp.replace('Hispanic/Latino', 0,inplace=True)
temp.replace('Native Hawaiian or other Pacific Islander', 1,inplace=True)
temp.replace('Asian', 0,inplace=True)
temp.replace('Other', 0,inplace=True)
temp.replace('White', 0,inplace=True)
C5 = temp

temp = trainingData['RACE CHECK ALL THAT APPLY_NCI']
temp.replace('American Indian or Alaskan Native', value=0,inplace=True)
temp.replace('Asian', 0,inplace=True)
temp.replace('Black or African-American', 0,inplace=True)
temp.replace('Hispanic/Latino', 0,inplace=True)
temp.replace('Native Hawaiian or other Pacific Islander', 0,inplace=True)
temp.replace('Asian', 1,inplace=True)
temp.replace('Other', 0,inplace=True)
temp.replace('White', 0,inplace=True)
C6 = temp

temp = trainingData['RACE CHECK ALL THAT APPLY_NCI']
temp.replace('American Indian or Alaskan Native', value=0,inplace=True)
temp.replace('Asian', 0,inplace=True)
temp.replace('Black or African-American', 0,inplace=True)
temp.replace('Hispanic/Latino', 0,inplace=True)
temp.replace('Native Hawaiian or other Pacific Islander', 0,inplace=True)
temp.replace('Asian', 0,inplace=True)
temp.replace('Other', 1,inplace=True)
temp.replace('White', 0,inplace=True)
C7 = temp


temp = trainingData['RACE CHECK ALL THAT APPLY_NCI']
temp.replace('American Indian or Alaskan Native', value=0,inplace=True)
temp.replace('Asian', 0,inplace=True)
temp.replace('Black or African-American', 0,inplace=True)
temp.replace('Hispanic/Latino', 0,inplace=True)
temp.replace('Native Hawaiian or other Pacific Islander', 0,inplace=True)
temp.replace('Asian', 0,inplace=True)
temp.replace('Other', 0,inplace=True)
temp.replace('White', 1,inplace=True)
C8 = temp

#VETERAN_NCI
temp = trainingData['VETERAN_NCI']
temp.replace('Yes',value=1,inplace=True)
temp.replace('No',0,inplace=True)
D1 = temp

temp = trainingData['VETERAN_NCI']
temp.replace('Yes',value=0,inplace=True)
temp.replace('No',1,inplace=True)
D2 = temp

#FAMILY TYPE_NCI
temp = trainingData['FAMILY TYPE_NCI']
temp.replace('Adult Couple',value=1,inplace=True)
temp.replace('Adult Family (no childeren udner 18)',0,inplace=True)
temp.replace('Family Headed by Grandparent or other Guardian', 0, inplace=True)
temp.replace('Individual Female', 0, inplace=True) 
temp.replace('Individual Male', 0, inplace=True) 
temp.replace('Single Parent Family (Female Head of Household)', 0, inplace=True) 
temp.replace('Single Parent Family (Male Head of Household)', 0, inplace=True)
temp.replace('Two Parent Family', 0, inplace=True) 
E1 = temp

temp = trainingData['FAMILY TYPE_NCI']
temp.replace('Adult Couple',value=0,inplace=True)
temp.replace('Adult Family (no childeren udner 18)',1,inplace=True)
temp.replace('Family Headed by Grandparent or other Guardian', 0, inplace=True)
temp.replace('Individual Female', 0, inplace=True) 
temp.replace('Individual Male', 0, inplace=True) 
temp.replace('Single Parent Family (Female Head of Household)', 0, inplace=True) 
temp.replace('Single Parent Family (Male Head of Household)', 0, inplace=True)
temp.replace('Two Parent Family', 0, inplace=True) 
E2 = temp

temp = trainingData['FAMILY TYPE_NCI']
temp.replace('Adult Couple',value=0,inplace=True)
temp.replace('Adult Family (no childeren udner 18)',1,inplace=True)
temp.replace('Family Headed by Grandparent or other Guardian', 0, inplace=True)
temp.replace('Individual Female', 0, inplace=True) 
temp.replace('Individual Male', 0, inplace=True) 
temp.replace('Single Parent Family (Female Head of Household)', 0, inplace=True) 
temp.replace('Single Parent Family (Male Head of Household)', 0, inplace=True)
temp.replace('Two Parent Family', 0, inplace=True) 
E3 = temp

temp = trainingData['FAMILY TYPE_NCI']
temp.replace('Adult Couple',value=0,inplace=True)
temp.replace('Adult Family (no childeren udner 18)',0,inplace=True)
temp.replace('Family Headed by Grandparent or other Guardian', 1, inplace=True)
temp.replace('Individual Female', 0, inplace=True) 
temp.replace('Individual Male', 0, inplace=True) 
temp.replace('Single Parent Family (Female Head of Household)', 0, inplace=True) 
temp.replace('Single Parent Family (Male Head of Household)', 0, inplace=True)
temp.replace('Two Parent Family', 0, inplace=True) 
E4 = temp

temp = trainingData['FAMILY TYPE_NCI']
temp.replace('Adult Couple',value=0,inplace=True)
temp.replace('Adult Family (no childeren udner 18)',0,inplace=True)
temp.replace('Family Headed by Grandparent or other Guardian', 0, inplace=True)
temp.replace('Individual Female', 1, inplace=True) 
temp.replace('Individual Male', 0, inplace=True) 
temp.replace('Single Parent Family (Female Head of Household)', 0, inplace=True) 
temp.replace('Single Parent Family (Male Head of Household)', 0, inplace=True)
temp.replace('Two Parent Family', 0, inplace=True) 
E5 = temp

temp = trainingData['FAMILY TYPE_NCI']
temp.replace('Adult Couple',value=0,inplace=True)
temp.replace('Adult Family (no childeren udner 18)',0,inplace=True)
temp.replace('Family Headed by Grandparent or other Guardian', 0, inplace=True)
temp.replace('Individual Female', 0, inplace=True) 
temp.replace('Individual Male', 1, inplace=True) 
temp.replace('Single Parent Family (Female Head of Household)', 0, inplace=True) 
temp.replace('Single Parent Family (Male Head of Household)', 0, inplace=True)
temp.replace('Two Parent Family', 0, inplace=True) 
E6 = temp

temp = trainingData['FAMILY TYPE_NCI']
temp.replace('Adult Couple',value=0,inplace=True)
temp.replace('Adult Family (no childeren udner 18)',0,inplace=True)
temp.replace('Family Headed by Grandparent or other Guardian', 0, inplace=True)
temp.replace('Individual Female', 0, inplace=True) 
temp.replace('Individual Male', 0, inplace=True) 
temp.replace('Single Parent Family (Female Head of Household)', 1, inplace=True) 
temp.replace('Single Parent Family (Male Head of Household)', 0, inplace=True)
temp.replace('Two Parent Family', 0, inplace=True) 
E7 = temp

temp = trainingData['FAMILY TYPE_NCI']
temp.replace('Adult Couple',value=0,inplace=True)
temp.replace('Adult Family (no childeren udner 18)',0,inplace=True)
temp.replace('Family Headed by Grandparent or other Guardian', 0, inplace=True)
temp.replace('Individual Female', 0, inplace=True) 
temp.replace('Individual Male', 0, inplace=True) 
temp.replace('Single Parent Family (Female Head of Household)', 0, inplace=True) 
temp.replace('Single Parent Family (Male Head of Household)', 1, inplace=True)
temp.replace('Two Parent Family', 0, inplace=True) 
E8 = temp

temp = trainingData['FAMILY TYPE_NCI']
temp.replace('Adult Couple',value=0,inplace=True)
temp.replace('Adult Family (no childeren udner 18)',0,inplace=True)
temp.replace('Family Headed by Grandparent or other Guardian', 0, inplace=True)
temp.replace('Individual Female', 0, inplace=True) 
temp.replace('Individual Male', 0, inplace=True) 
temp.replace('Single Parent Family (Female Head of Household)', 0, inplace=True) 
temp.replace('Single Parent Family (Male Head of Household)', 0, inplace=True)
temp.replace('Two Parent Family', 1, inplace=True) 
E9 = temp

#POST EVICT_NCI
temp = trainingData['POST EVICT_NCI']
temp.replace('Yes',value=1,inplace=True)
temp.replace('No',0,inplace=True)
F1 = temp

temp = trainingData['POST EVICT_NCI']
temp.replace('Yes',value=0,inplace=True)
temp.replace('No',1,inplace=True)
F2 = temp

#REASON THE CLIENT FELL INTO ARREARS_NCI
temp = trainingData['REASON THE CLIENT FELL INTO ARREARS_NCI']
temp.replace('Discord with Landlord',value=1,inplace=True)
temp.replace('Domestic Violence/Dispute',0,inplace=True)
temp.replace('Financial Mismanagement',0,inplace=True)
temp.replace('Funeral Expense',0,inplace=True)
temp.replace('Loss of Third Party',0,inplace=True)
temp.replace('Medical Issue',0,inplace=True)
temp.replace('Mental Health Issue',0,inplace=True)
temp.replace('Other',0,inplace=True)
temp.replace('Problem with Benefits',0,inplace=True)
temp.replace('Rent Increase',0,inplace=True)
temp.replace('Substance Abuse Issue',0,inplace=True)
temp.replace('Temporary Unemployment',0,inplace=True)
temp.replace('Underemployment',0,inplace=True)
temp.replace('Unexpected Financial Emergency',0,inplace=True)
G1 = temp

temp = trainingData['REASON THE CLIENT FELL INTO ARREARS_NCI']
temp.replace('Discord with Landlord',value=0,inplace=True)
temp.replace('Domestic Violence/Dispute',1,inplace=True)
temp.replace('Financial Mismanagement',0,inplace=True)
temp.replace('Funeral Expense',0,inplace=True)
temp.replace('Loss of Third Party',0,inplace=True)
temp.replace('Medical Issue',0,inplace=True)
temp.replace('Mental Health Issue',0,inplace=True)
temp.replace('Other',0,inplace=True)
temp.replace('Problem with Benefits',0,inplace=True)
temp.replace('Rent Increase',0,inplace=True)
temp.replace('Substance Abuse Issue',0,inplace=True)
temp.replace('Temporary Unemployment',0,inplace=True)
temp.replace('Underemployment',0,inplace=True)
temp.replace('Unexpected Financial Emergency',0,inplace=True)
G2 = temp

temp = trainingData['REASON THE CLIENT FELL INTO ARREARS_NCI']
temp.replace('Discord with Landlord',value=0,inplace=True)
temp.replace('Domestic Violence/Dispute',0,inplace=True)
temp.replace('Financial Mismanagement',1,inplace=True)
temp.replace('Funeral Expense',0,inplace=True)
temp.replace('Loss of Third Party',0,inplace=True)
temp.replace('Medical Issue',0,inplace=True)
temp.replace('Mental Health Issue',0,inplace=True)
temp.replace('Other',0,inplace=True)
temp.replace('Problem with Benefits',0,inplace=True)
temp.replace('Rent Increase',0,inplace=True)
temp.replace('Substance Abuse Issue',0,inplace=True)
temp.replace('Temporary Unemployment',0,inplace=True)
temp.replace('Underemployment',0,inplace=True)
temp.replace('Unexpected Financial Emergency',0,inplace=True)
G3 = temp

temp = trainingData['REASON THE CLIENT FELL INTO ARREARS_NCI']
temp.replace('Discord with Landlord',value=0,inplace=True)
temp.replace('Domestic Violence/Dispute',0,inplace=True)
temp.replace('Financial Mismanagement',0,inplace=True)
temp.replace('Funeral Expense',1,inplace=True)
temp.replace('Loss of Third Party',0,inplace=True)
temp.replace('Medical Issue',0,inplace=True)
temp.replace('Mental Health Issue',0,inplace=True)
temp.replace('Other',0,inplace=True)
temp.replace('Problem with Benefits',0,inplace=True)
temp.replace('Rent Increase',0,inplace=True)
temp.replace('Substance Abuse Issue',0,inplace=True)
temp.replace('Temporary Unemployment',0,inplace=True)
temp.replace('Underemployment',0,inplace=True)
temp.replace('Unexpected Financial Emergency',0,inplace=True)
G4 = temp

temp = trainingData['REASON THE CLIENT FELL INTO ARREARS_NCI']
temp.replace('Discord with Landlord',value=0,inplace=True)
temp.replace('Domestic Violence/Dispute',0,inplace=True)
temp.replace('Financial Mismanagement',0,inplace=True)
temp.replace('Funeral Expense',0,inplace=True)
temp.replace('Loss of Third Party',1,inplace=True)
temp.replace('Medical Issue',0,inplace=True)
temp.replace('Mental Health Issue',0,inplace=True)
temp.replace('Other',0,inplace=True)
temp.replace('Problem with Benefits',0,inplace=True)
temp.replace('Rent Increase',0,inplace=True)
temp.replace('Substance Abuse Issue',0,inplace=True)
temp.replace('Temporary Unemployment',0,inplace=True)
temp.replace('Underemployment',0,inplace=True)
temp.replace('Unexpected Financial Emergency',0,inplace=True)
G5 = temp

temp = trainingData['REASON THE CLIENT FELL INTO ARREARS_NCI']
temp.replace('Discord with Landlord',value=0,inplace=True)
temp.replace('Domestic Violence/Dispute',0,inplace=True)
temp.replace('Financial Mismanagement',0,inplace=True)
temp.replace('Funeral Expense',0,inplace=True)
temp.replace('Loss of Third Party',0,inplace=True)
temp.replace('Medical Issue',1,inplace=True)
temp.replace('Mental Health Issue',0,inplace=True)
temp.replace('Other',0,inplace=True)
temp.replace('Problem with Benefits',0,inplace=True)
temp.replace('Rent Increase',0,inplace=True)
temp.replace('Substance Abuse Issue',0,inplace=True)
temp.replace('Temporary Unemployment',0,inplace=True)
temp.replace('Underemployment',0,inplace=True)
temp.replace('Unexpected Financial Emergency',0,inplace=True)
G6 = temp

temp = trainingData['REASON THE CLIENT FELL INTO ARREARS_NCI']
temp.replace('Discord with Landlord',value=0,inplace=True)
temp.replace('Domestic Violence/Dispute',0,inplace=True)
temp.replace('Financial Mismanagement',0,inplace=True)
temp.replace('Funeral Expense',0,inplace=True)
temp.replace('Loss of Third Party',0,inplace=True)
temp.replace('Medical Issue',0,inplace=True)
temp.replace('Mental Health Issue',1,inplace=True)
temp.replace('Other',0,inplace=True)
temp.replace('Problem with Benefits',0,inplace=True)
temp.replace('Rent Increase',0,inplace=True)
temp.replace('Substance Abuse Issue',0,inplace=True)
temp.replace('Temporary Unemployment',0,inplace=True)
temp.replace('Underemployment',0,inplace=True)
temp.replace('Unexpected Financial Emergency',0,inplace=True)
G7 = temp

temp = trainingData['REASON THE CLIENT FELL INTO ARREARS_NCI']
temp.replace('Discord with Landlord',value=0,inplace=True)
temp.replace('Domestic Violence/Dispute',0,inplace=True)
temp.replace('Financial Mismanagement',0,inplace=True)
temp.replace('Funeral Expense',0,inplace=True)
temp.replace('Loss of Third Party',0,inplace=True)
temp.replace('Medical Issue',0,inplace=True)
temp.replace('Mental Health Issue',0,inplace=True)
temp.replace('Other',1,inplace=True)
temp.replace('Problem with Benefits',0,inplace=True)
temp.replace('Rent Increase',0,inplace=True)
temp.replace('Substance Abuse Issue',0,inplace=True)
temp.replace('Temporary Unemployment',0,inplace=True)
temp.replace('Underemployment',0,inplace=True)
temp.replace('Unexpected Financial Emergency',0,inplace=True)
G8 = temp

temp = trainingData['REASON THE CLIENT FELL INTO ARREARS_NCI']
temp.replace('Discord with Landlord',value=0,inplace=True)
temp.replace('Domestic Violence/Dispute',0,inplace=True)
temp.replace('Financial Mismanagement',0,inplace=True)
temp.replace('Funeral Expense',0,inplace=True)
temp.replace('Loss of Third Party',0,inplace=True)
temp.replace('Medical Issue',0,inplace=True)
temp.replace('Mental Health Issue',0,inplace=True)
temp.replace('Other',0,inplace=True)
temp.replace('Problem with Benefits',1,inplace=True)
temp.replace('Rent Increase',0,inplace=True)
temp.replace('Substance Abuse Issue',0,inplace=True)
temp.replace('Temporary Unemployment',0,inplace=True)
temp.replace('Underemployment',0,inplace=True)
temp.replace('Unexpected Financial Emergency',0,inplace=True)
G9 = temp

temp = trainingData['REASON THE CLIENT FELL INTO ARREARS_NCI']
temp.replace('Discord with Landlord',value=0,inplace=True)
temp.replace('Domestic Violence/Dispute',0,inplace=True)
temp.replace('Financial Mismanagement',0,inplace=True)
temp.replace('Funeral Expense',0,inplace=True)
temp.replace('Loss of Third Party',0,inplace=True)
temp.replace('Medical Issue',0,inplace=True)
temp.replace('Mental Health Issue',0,inplace=True)
temp.replace('Other',0,inplace=True)
temp.replace('Problem with Benefits',0,inplace=True)
temp.replace('Rent Increase',1,inplace=True)
temp.replace('Substance Abuse Issue',0,inplace=True)
temp.replace('Temporary Unemployment',0,inplace=True)
temp.replace('Underemployment',0,inplace=True)
temp.replace('Unexpected Financial Emergency',0,inplace=True)
G10 = temp

temp = trainingData['REASON THE CLIENT FELL INTO ARREARS_NCI']
temp.replace('Discord with Landlord',value=0,inplace=True)
temp.replace('Domestic Violence/Dispute',0,inplace=True)
temp.replace('Financial Mismanagement',0,inplace=True)
temp.replace('Funeral Expense',0,inplace=True)
temp.replace('Loss of Third Party',0,inplace=True)
temp.replace('Medical Issue',0,inplace=True)
temp.replace('Mental Health Issue',0,inplace=True)
temp.replace('Other',0,inplace=True)
temp.replace('Problem with Benefits',0,inplace=True)
temp.replace('Rent Increase',0,inplace=True)
temp.replace('Substance Abuse Issue',1,inplace=True)
temp.replace('Temporary Unemployment',0,inplace=True)
temp.replace('Underemployment',0,inplace=True)
temp.replace('Unexpected Financial Emergency',0,inplace=True)
G11 = temp

temp = trainingData['REASON THE CLIENT FELL INTO ARREARS_NCI']
temp.replace('Discord with Landlord',value=0,inplace=True)
temp.replace('Domestic Violence/Dispute',0,inplace=True)
temp.replace('Financial Mismanagement',0,inplace=True)
temp.replace('Funeral Expense',0,inplace=True)
temp.replace('Loss of Third Party',0,inplace=True)
temp.replace('Medical Issue',0,inplace=True)
temp.replace('Mental Health Issue',0,inplace=True)
temp.replace('Other',0,inplace=True)
temp.replace('Problem with Benefits',0,inplace=True)
temp.replace('Rent Increase',0,inplace=True)
temp.replace('Substance Abuse Issue',0,inplace=True)
temp.replace('Temporary Unemployment',1,inplace=True)
temp.replace('Underemployment',0,inplace=True)
temp.replace('Unexpected Financial Emergency',0,inplace=True)
G12 = temp

temp = trainingData['REASON THE CLIENT FELL INTO ARREARS_NCI']
temp.replace('Discord with Landlord',value=0,inplace=True)
temp.replace('Domestic Violence/Dispute',0,inplace=True)
temp.replace('Financial Mismanagement',0,inplace=True)
temp.replace('Funeral Expense',0,inplace=True)
temp.replace('Loss of Third Party',0,inplace=True)
temp.replace('Medical Issue',0,inplace=True)
temp.replace('Mental Health Issue',0,inplace=True)
temp.replace('Other',0,inplace=True)
temp.replace('Problem with Benefits',0,inplace=True)
temp.replace('Rent Increase',0,inplace=True)
temp.replace('Substance Abuse Issue',0,inplace=True)
temp.replace('Temporary Unemployment',0,inplace=True)
temp.replace('Underemployment',1,inplace=True)
temp.replace('Unexpected Financial Emergency',0,inplace=True)
G13 = temp

temp = trainingData['REASON THE CLIENT FELL INTO ARREARS_NCI']
temp.replace('Discord with Landlord',value=0,inplace=True)
temp.replace('Domestic Violence/Dispute',0,inplace=True)
temp.replace('Financial Mismanagement',0,inplace=True)
temp.replace('Funeral Expense',0,inplace=True)
temp.replace('Loss of Third Party',0,inplace=True)
temp.replace('Medical Issue',0,inplace=True)
temp.replace('Mental Health Issue',0,inplace=True)
temp.replace('Other',0,inplace=True)
temp.replace('Problem with Benefits',0,inplace=True)
temp.replace('Rent Increase',0,inplace=True)
temp.replace('Substance Abuse Issue',0,inplace=True)
temp.replace('Temporary Unemployment',0,inplace=True)
temp.replace('Underemployment',0,inplace=True)
temp.replace('Unexpected Financial Emergency',1,inplace=True)
G14 = temp
#print(trainingData.head())

#CHECK OFF ANY HOUSING SUBSIDIES THAT CLIENT MAY BE RECEIVING_NCI
temp = trainingData['CHECK OFF ANY HOUSING SUBSIDIES THAT CLIENT MAY BE RECEIVING_NCI']
temp.replace('DRIE',value=1,inplace=True)
temp.replace('FEPS/Jiggetts',0,inplace=True)
temp.replace('HSP',0,inplace=True)
temp.replace('Preferential Rent',0,inplace=True)
temp.replace('SCRIE',0,inplace=True)
temp.replace('Section 8',0,inplace=True)
H1 = temp

temp = trainingData['CHECK OFF ANY HOUSING SUBSIDIES THAT CLIENT MAY BE RECEIVING_NCI']
temp.replace('DRIE',value=0,inplace=True)
temp.replace('FEPS/Jiggetts',1,inplace=True)
temp.replace('HSP',0,inplace=True)
temp.replace('Preferential Rent',0,inplace=True)
temp.replace('SCRIE',0,inplace=True)
temp.replace('Section 8',0,inplace=True)
H2 = temp

temp = trainingData['CHECK OFF ANY HOUSING SUBSIDIES THAT CLIENT MAY BE RECEIVING_NCI']
temp.replace('DRIE',value=0,inplace=True)
temp.replace('FEPS/Jiggetts',0,inplace=True)
temp.replace('HSP',1,inplace=True)
temp.replace('Preferential Rent',0,inplace=True)
temp.replace('SCRIE',0,inplace=True)
temp.replace('Section 8',0,inplace=True)
H3 = temp

temp = trainingData['CHECK OFF ANY HOUSING SUBSIDIES THAT CLIENT MAY BE RECEIVING_NCI']
temp.replace('DRIE',value=0,inplace=True)
temp.replace('FEPS/Jiggetts',0,inplace=True)
temp.replace('HSP',0,inplace=True)
temp.replace('Preferential Rent',1,inplace=True)
temp.replace('SCRIE',0,inplace=True)
temp.replace('Section 8',0,inplace=True)
H4 = temp

temp = trainingData['CHECK OFF ANY HOUSING SUBSIDIES THAT CLIENT MAY BE RECEIVING_NCI']
temp.replace('DRIE',value=0,inplace=True)
temp.replace('FEPS/Jiggetts',0,inplace=True)
temp.replace('HSP',0,inplace=True)
temp.replace('Preferential Rent',0,inplace=True)
temp.replace('SCRIE',1,inplace=True)
temp.replace('Section 8',0,inplace=True)
H5 = temp

temp = trainingData['CHECK OFF ANY HOUSING SUBSIDIES THAT CLIENT MAY BE RECEIVING_NCI']
temp.replace('DRIE',value=0,inplace=True)
temp.replace('FEPS/Jiggetts',0,inplace=True)
temp.replace('HSP',0,inplace=True)
temp.replace('Preferential Rent',0,inplace=True)
temp.replace('SCRIE',0,inplace=True)
temp.replace('Section 8',1,inplace=True)
H6 = temp

#TYPE OF HOUSING WHERE CLIENT RESIDES_NCI
temp = trainingData['TYPE OF HOUSING WHERE CLIENT RESIDES_NCI']
temp.replace('Coop',value=1,inplace=True)
temp.replace('HPD',0,inplace=True)
temp.replace('Mitchell Lama',0,inplace=True)
temp.replace('NYCHA',0,inplace=True)
temp.replace('Regular Market Rate Rental',0,inplace=True)
temp.replace('Rent Stabilized',0,inplace=True)
temp.replace('SRO',0,inplace=True)
I1 = temp

temp = trainingData['TYPE OF HOUSING WHERE CLIENT RESIDES_NCI']
temp.replace('Coop',value=0,inplace=True)
temp.replace('HPD',1,inplace=True)
temp.replace('Mitchell Lama',0,inplace=True)
temp.replace('NYCHA',0,inplace=True)
temp.replace('Regular Market Rate Rental',0,inplace=True)
temp.replace('Rent Stabilized',0,inplace=True)
temp.replace('SRO',0,inplace=True)
I2 = temp

temp = trainingData['TYPE OF HOUSING WHERE CLIENT RESIDES_NCI']
temp.replace('Coop',value=0,inplace=True)
temp.replace('HPD',0,inplace=True)
temp.replace('Mitchell Lama',1,inplace=True)
temp.replace('NYCHA',0,inplace=True)
temp.replace('Regular Market Rate Rental',0,inplace=True)
temp.replace('Rent Stabilized',0,inplace=True)
temp.replace('SRO',0,inplace=True)
I3 = temp

temp = trainingData['TYPE OF HOUSING WHERE CLIENT RESIDES_NCI']
temp.replace('Coop',value=0,inplace=True)
temp.replace('HPD',0,inplace=True)
temp.replace('Mitchell Lama',0,inplace=True)
temp.replace('NYCHA',1,inplace=True)
temp.replace('Regular Market Rate Rental',0,inplace=True)
temp.replace('Rent Stabilized',0,inplace=True)
temp.replace('SRO',0,inplace=True)
I4 = temp

temp = trainingData['TYPE OF HOUSING WHERE CLIENT RESIDES_NCI']
temp.replace('Coop',value=0,inplace=True)
temp.replace('HPD',0,inplace=True)
temp.replace('Mitchell Lama',0,inplace=True)
temp.replace('NYCHA',0,inplace=True)
temp.replace('Regular Market Rate Rental',1,inplace=True)
temp.replace('Rent Stabilized',0,inplace=True)
temp.replace('SRO',0,inplace=True)
I5 = temp

temp = trainingData['TYPE OF HOUSING WHERE CLIENT RESIDES_NCI']
temp.replace('Coop',value=0,inplace=True)
temp.replace('HPD',0,inplace=True)
temp.replace('Mitchell Lama',0,inplace=True)
temp.replace('NYCHA',0,inplace=True)
temp.replace('Regular Market Rate Rental',0,inplace=True)
temp.replace('Rent Stabilized',1,inplace=True)
temp.replace('SRO',0,inplace=True)
I6 = temp

temp = trainingData['TYPE OF HOUSING WHERE CLIENT RESIDES_NCI']
temp.replace('Coop',value=0,inplace=True)
temp.replace('HPD',0,inplace=True)
temp.replace('Mitchell Lama',0,inplace=True)
temp.replace('NYCHA',0,inplace=True)
temp.replace('Regular Market Rate Rental',0,inplace=True)
temp.replace('Rent Stabilized',0,inplace=True)
temp.replace('SRO',1,inplace=True)
I7 = temp

#CURRENT BOROUGH
temp = trainingData['CURRENT BOROUGH']
temp.replace('Bronx', value=1,inplace=True)
temp.replace('Brooklyn',0,inplace=True)
temp.replace('Manhattan',0,inplace=True)
temp.replace('Outside New York City',0,inplace=True)
temp.replace('Queens',0,inplace=True)
temp.replace('Staten Island',0,inplace=True)
J1=temp

temp = trainingData['CURRENT BOROUGH']
temp.replace('Bronx', value=0,inplace=True)
temp.replace('Brooklyn',1,inplace=True)
temp.replace('Manhattan',0,inplace=True)
temp.replace('Outside New York City',0,inplace=True)
temp.replace('Queens',0,inplace=True)
temp.replace('Staten Island',0,inplace=True)
J2=temp

temp = trainingData['CURRENT BOROUGH']
temp.replace('Bronx', value=0,inplace=True)
temp.replace('Brooklyn',0,inplace=True)
temp.replace('Manhattan',1,inplace=True)
temp.replace('Outside New York City',0,inplace=True)
temp.replace('Queens',0,inplace=True)
temp.replace('Staten Island',0,inplace=True)
J3=temp

temp = trainingData['CURRENT BOROUGH']
temp.replace('Bronx', value=0,inplace=True)
temp.replace('Brooklyn',0,inplace=True)
temp.replace('Manhattan',0,inplace=True)
temp.replace('Outside New York City',1,inplace=True)
temp.replace('Queens',0,inplace=True)
temp.replace('Staten Island',0,inplace=True)
J4=temp

temp = trainingData['CURRENT BOROUGH']
temp.replace('Bronx', value=0,inplace=True)
temp.replace('Brooklyn',0,inplace=True)
temp.replace('Manhattan',0,inplace=True)
temp.replace('Outside New York City',0,inplace=True)
temp.replace('Queens',1,inplace=True)
temp.replace('Staten Island',0,inplace=True)
J5=temp

temp = trainingData['CURRENT BOROUGH']
temp.replace('Bronx', value=0,inplace=True)
temp.replace('Brooklyn',0,inplace=True)
temp.replace('Manhattan',0,inplace=True)
temp.replace('Outside New York City',0,inplace=True)
temp.replace('Queens',0,inplace=True)
temp.replace('Staten Island',1,inplace=True)
J6=temp

#DISABLINGCONDITIONS15237_NCI
temp = trainingData['DISABLINGCONDITIONS15237_NCI']
temp.replace('Yes',value=1,inplace=True)
temp.replace('No',0,inplace=True)
temp.replace('Refused',0,inplace=True)
temp.replace('Don&#39;t Know',0,inplace=True)
K1 = temp

temp = trainingData['DISABLINGCONDITIONS15237_NCI']
temp.replace('Yes',value=0,inplace=True)
temp.replace('No',1,inplace=True)
temp.replace('Refused',0,inplace=True)
temp.replace('Don&#39;t Know',0,inplace=True)
K2 = temp

temp = trainingData['DISABLINGCONDITIONS15237_NCI']
temp.replace('Yes',value=0,inplace=True)
temp.replace('No',0,inplace=True)
temp.replace('Refused',1,inplace=True)
temp.replace('Don&#39;t Know',0,inplace=True)
K3 = temp

temp = trainingData['DISABLINGCONDITIONS15237_NCI']
temp.replace('Yes',value=0,inplace=True)
temp.replace('No',0,inplace=True)
temp.replace('Refused',0,inplace=True)
temp.replace('Don&#39;t Know',1,inplace=True)
K4 = temp

#PHYSICALDISABILITY15238_NCI
temp = trainingData['PHYSICALDISABILITY15238_NCI']
temp.replace('Yes',value=1,inplace=True)
temp.replace('No',0,inplace=True)
L1 = temp

temp = trainingData['PHYSICALDISABILITY15238_NCI']
temp.replace('Yes',value=0,inplace=True)
temp.replace('No',1,inplace=True)
L2 = temp

#DEVELOPMENTALDISABILITY15239_NCI
temp = trainingData['DEVELOPMENTALDISABILITY15239_NCI']
temp.replace('Yes',value=1,inplace=True)
temp.replace('No',0,inplace=True)
M1 = temp

temp = trainingData['DEVELOPMENTALDISABILITY15239_NCI']
temp.replace('Yes',value=0,inplace=True)
temp.replace('No',1,inplace=True)
M2 = temp

#HIVAIDSSTATUS15240_NCI
temp = trainingData['HIVAIDSSTATUS15240_NCI']
temp.replace('Yes',value=1,inplace=True)
temp.replace('No',0,inplace=True)
N1 = temp

temp = trainingData['HIVAIDSSTATUS15240_NCI']
temp.replace('Yes',value=0,inplace=True)
temp.replace('No',1,inplace=True)
N2 = temp

#MENTALHEALTHPROBLEM15241_NCI
temp = trainingData['MENTALHEALTHPROBLEM15241_NCI']
temp.replace('Yes',value=1,inplace=True)
temp.replace('No',0,inplace=True)
O1 = temp

temp = trainingData['MENTALHEALTHPROBLEM15241_NCI']
temp.replace('Yes',value=0,inplace=True)
temp.replace('No',1,inplace=True)
O2 = temp

#SUBSTANCEABUSEPROBLEM15243_NCI
temp = trainingData['SUBSTANCEABUSEPROBLEM15243_NCI']
temp.replace('Alcohol abuse',value=1,inplace=True)
temp.replace('Drug abuse',0,inplace=True)
temp.replace('Both',0,inplace=True)
P1 = temp

temp = trainingData['SUBSTANCEABUSEPROBLEM15243_NCI']
temp.replace('Yes',value=0,inplace=True)
temp.replace('No',1,inplace=True)
temp.replace('Both',0,inplace=True)
P2 = temp

temp = trainingData['SUBSTANCEABUSEPROBLEM15243_NCI']
temp.replace('Yes',value=0,inplace=True)
temp.replace('No',0,inplace=True)
temp.replace('Both',1,inplace=True)
P3 = temp

#EVER RECEIVED TREATMENT FOR MENTAL HEALTH_NCI
temp = trainingData['EVER RECEIVED TREATMENT FOR MENTAL HEALTH_NCI']
temp.replace('Yes',value=1,inplace=True)
temp.replace('No',0,inplace=True)
Q1 = temp

temp = trainingData['EVER RECEIVED TREATMENT FOR MENTAL HEALTH_NCI']
temp.replace('Yes',value=0,inplace=True)
temp.replace('No',1,inplace=True)
Q2 = temp

#CURRENTLY IN TREATMENT FOR MENTAL HEALTH_NCI
temp = trainingData['CURRENTLY IN TREATMENT FOR MENTAL HEALTH_NCI']
temp.replace('Yes',value=1,inplace=True)
temp.replace('No',0,inplace=True)
R1 = temp

temp = trainingData['CURRENTLY IN TREATMENT FOR MENTAL HEALTH_NCI']
temp.replace('Yes',value=0,inplace=True)
temp.replace('No',1,inplace=True)
R2 = temp

#CURRENTLY IN TREATMENT FOR SUBSTANCE USEDEPENDENCE_NCI
temp = trainingData['CURRENTLY IN TREATMENT FOR SUBSTANCE USEDEPENDENCE_NCI']
temp.replace('Yes',value=1,inplace=True)
temp.replace('No',0,inplace=True)
S1 = temp

temp = trainingData['CURRENTLY IN TREATMENT FOR SUBSTANCE USEDEPENDENCE_NCI']
temp.replace('Yes',value=0,inplace=True)
temp.replace('No',1,inplace=True)
S2 = temp

#EVER RECEIVED TREATMENT FOR SUBSTANCE USEDEPENDENCE_NCI
temp = trainingData['EVER RECEIVED TREATMENT FOR SUBSTANCE USEDEPENDENCE_NCI']
temp.replace('Yes',value=1,inplace=True)
temp.replace('No',0,inplace=True)
T1 = temp

temp = trainingData['EVER RECEIVED TREATMENT FOR SUBSTANCE USEDEPENDENCE_NCI']
temp.replace('Yes',value=0,inplace=True)
temp.replace('No',1,inplace=True)
T2 = temp

#DOMESTICVIOLENCE15245_NCI
temp = trainingData['DOMESTICVIOLENCE15245_NCI']
temp.replace('Yes',value=1,inplace=True)
temp.replace('No',0,inplace=True)
U1 = temp

temp = trainingData['DOMESTICVIOLENCE15245_NCI']
temp.replace('Yes',value=0,inplace=True)
temp.replace('No',1,inplace=True)
U2 = temp

#CURRENTLY IN DV SITUATION_NCI
temp = trainingData['CURRENTLY IN DV SITUATION_NCI']
temp.replace('Yes',value=1,inplace=True)
temp.replace('No',0,inplace=True)
V1 = temp

temp = trainingData['CURRENTLY IN DV SITUATION_NCI']
temp.replace('Yes',value=0,inplace=True)
temp.replace('No',1,inplace=True)
V2 = temp

#PREGNANCYSTATUS15247_NCI
temp = trainingData['PREGNANCYSTATUS15247_NCI']
temp.replace('Yes',value=1,inplace=True)
temp.replace('No',0,inplace=True)
v1 = temp

temp = trainingData['PREGNANCYSTATUS15247_NCI']
temp.replace('Yes',value=0,inplace=True)
temp.replace('No',1,inplace=True)
v2 = temp

#HIGHESTSCHOOLLEVEL15257_x
temp = trainingData['HIGHESTSCHOOLLEVEL15257_x']
temp.replace('10th grade',value=1,inplace=True)
temp.replace('11th grade',0,inplace=True)
temp.replace('12th grade, no diploma',0,inplace=True)
temp.replace('5th grade or 6th grade',0,inplace=True)
temp.replace('7th grade or 8th grade',0,inplace=True)
temp.replace('9th grade',0,inplace=True)
temp.replace('GED',0,inplace=True)
temp.replace('High school diploma',0,inplace=True)
temp.replace('No schooling completed',0,inplace=True)
temp.replace('Nursery school to 4th grade',0,inplace=True)
temp.replace('Post-secondary school',0,inplace=True)
W1 = temp

temp = trainingData['HIGHESTSCHOOLLEVEL15257_x']
temp.replace('10th grade',value=0,inplace=True)
temp.replace('11th grade',1,inplace=True)
temp.replace('12th grade, no diploma',0,inplace=True)
temp.replace('5th grade or 6th grade',0,inplace=True)
temp.replace('7th grade or 8th grade',0,inplace=True)
temp.replace('9th grade',0,inplace=True)
temp.replace('GED',0,inplace=True)
temp.replace('High school diploma',0,inplace=True)
temp.replace('No schooling completed',0,inplace=True)
temp.replace('Nursery school to 4th grade',0,inplace=True)
temp.replace('Post-secondary school',0,inplace=True)
W2 = temp

temp = trainingData['HIGHESTSCHOOLLEVEL15257_x']
temp.replace('10th grade',value=0,inplace=True)
temp.replace('11th grade',0,inplace=True)
temp.replace('12th grade, no diploma',1,inplace=True)
temp.replace('5th grade or 6th grade',0,inplace=True)
temp.replace('7th grade or 8th grade',0,inplace=True)
temp.replace('9th grade',0,inplace=True)
temp.replace('GED',0,inplace=True)
temp.replace('High school diploma',0,inplace=True)
temp.replace('No schooling completed',0,inplace=True)
temp.replace('Nursery school to 4th grade',0,inplace=True)
temp.replace('Post-secondary school',0,inplace=True)
W3 = temp

temp = trainingData['HIGHESTSCHOOLLEVEL15257_x']
temp.replace('10th grade',value=0,inplace=True)
temp.replace('11th grade',0,inplace=True)
temp.replace('12th grade, no diploma',0,inplace=True)
temp.replace('5th grade or 6th grade',1,inplace=True)
temp.replace('7th grade or 8th grade',0,inplace=True)
temp.replace('9th grade',0,inplace=True)
temp.replace('GED',0,inplace=True)
temp.replace('High school diploma',0,inplace=True)
temp.replace('No schooling completed',0,inplace=True)
temp.replace('Nursery school to 4th grade',0,inplace=True)
temp.replace('Post-secondary school',0,inplace=True)
W4 = temp

temp = trainingData['HIGHESTSCHOOLLEVEL15257_x']
temp.replace('10th grade',value=0,inplace=True)
temp.replace('11th grade',0,inplace=True)
temp.replace('12th grade, no diploma',0,inplace=True)
temp.replace('5th grade or 6th grade',0,inplace=True)
temp.replace('7th grade or 8th grade',1,inplace=True)
temp.replace('9th grade',0,inplace=True)
temp.replace('GED',0,inplace=True)
temp.replace('High school diploma',0,inplace=True)
temp.replace('No schooling completed',0,inplace=True)
temp.replace('Nursery school to 4th grade',0,inplace=True)
temp.replace('Post-secondary school',0,inplace=True)
W5 = temp

temp = trainingData['HIGHESTSCHOOLLEVEL15257_x']
temp.replace('10th grade',value=0,inplace=True)
temp.replace('11th grade',0,inplace=True)
temp.replace('12th grade, no diploma',0,inplace=True)
temp.replace('5th grade or 6th grade',0,inplace=True)
temp.replace('7th grade or 8th grade',0,inplace=True)
temp.replace('9th grade',1,inplace=True)
temp.replace('GED',0,inplace=True)
temp.replace('High school diploma',0,inplace=True)
temp.replace('No schooling completed',0,inplace=True)
temp.replace('Nursery school to 4th grade',0,inplace=True)
temp.replace('Post-secondary school',0,inplace=True)
W6 = temp

temp = trainingData['HIGHESTSCHOOLLEVEL15257_x']
temp.replace('10th grade',value=0,inplace=True)
temp.replace('11th grade',0,inplace=True)
temp.replace('12th grade, no diploma',0,inplace=True)
temp.replace('5th grade or 6th grade',0,inplace=True)
temp.replace('7th grade or 8th grade',0,inplace=True)
temp.replace('9th grade',0,inplace=True)
temp.replace('GED',1,inplace=True)
temp.replace('High school diploma',0,inplace=True)
temp.replace('No schooling completed',0,inplace=True)
temp.replace('Nursery school to 4th grade',0,inplace=True)
temp.replace('Post-secondary school',0,inplace=True)
W7 = temp

temp = trainingData['HIGHESTSCHOOLLEVEL15257_x']
temp.replace('10th grade',value=0,inplace=True)
temp.replace('11th grade',0,inplace=True)
temp.replace('12th grade, no diploma',0,inplace=True)
temp.replace('5th grade or 6th grade',0,inplace=True)
temp.replace('7th grade or 8th grade',0,inplace=True)
temp.replace('9th grade',0,inplace=True)
temp.replace('GED',0,inplace=True)
temp.replace('High school diploma',1,inplace=True)
temp.replace('No schooling completed',0,inplace=True)
temp.replace('Nursery school to 4th grade',0,inplace=True)
temp.replace('Post-secondary school',0,inplace=True)
W8 = temp

temp = trainingData['HIGHESTSCHOOLLEVEL15257_x']
temp.replace('10th grade',value=0,inplace=True)
temp.replace('11th grade',0,inplace=True)
temp.replace('12th grade, no diploma',0,inplace=True)
temp.replace('5th grade or 6th grade',0,inplace=True)
temp.replace('7th grade or 8th grade',0,inplace=True)
temp.replace('9th grade',0,inplace=True)
temp.replace('GED',0,inplace=True)
temp.replace('High school diploma',0,inplace=True)
temp.replace('No schooling completed',1,inplace=True)
temp.replace('Nursery school to 4th grade',0,inplace=True)
temp.replace('Post-secondary school',0,inplace=True)
W9 = temp

temp = trainingData['HIGHESTSCHOOLLEVEL15257_x']
temp.replace('10th grade',value=0,inplace=True)
temp.replace('11th grade',0,inplace=True)
temp.replace('12th grade, no diploma',0,inplace=True)
temp.replace('5th grade or 6th grade',0,inplace=True)
temp.replace('7th grade or 8th grade',0,inplace=True)
temp.replace('9th grade',0,inplace=True)
temp.replace('GED',0,inplace=True)
temp.replace('High school diploma',0,inplace=True)
temp.replace('No schooling completed',0,inplace=True)
temp.replace('Nursery school to 4th grade',1,inplace=True)
temp.replace('Post-secondary school',0,inplace=True)
W10 = temp

temp = trainingData['HIGHESTSCHOOLLEVEL15257_x']
temp.replace('10th grade',value=0,inplace=True)
temp.replace('11th grade',0,inplace=True)
temp.replace('12th grade, no diploma',0,inplace=True)
temp.replace('5th grade or 6th grade',0,inplace=True)
temp.replace('7th grade or 8th grade',0,inplace=True)
temp.replace('9th grade',0,inplace=True)
temp.replace('GED',0,inplace=True)
temp.replace('High school diploma',0,inplace=True)
temp.replace('No schooling completed',0,inplace=True)
temp.replace('Nursery school to 4th grade',0,inplace=True)
temp.replace('Post-secondary school',1,inplace=True)
W11 = temp

#BENEFITSSOURCECODE15298_NCI
temp=trainingData['BENEFITSSOURCECODE15298_NCI']
temp.replace('Food stamps or money for food or a benefits card', value=1,inplace=True)
temp.replace('MEDICAID Health Insurance Program (or local name)',0,inplace=True)
temp.replace('MEDICARE Health Insurance Program (or local name)',0,inplace=True)
temp.replace('Other Source',0,inplace=True)
temp.replace('Section 8,public housing,or other rental assistance',0,inplace=True)
temp.replace('Special Supplemental Nutrition Program for Women,Infants and Children (WIC)',0,inplace=True)
temp.replace('State Children&#39;s Health Insureance Program (or local name)',0,inplace=True)
temp.replace('TANF Child Care Services (or local name)',0,inplace=True)
temp.replace('TANF Transportation servies (or local name)',0,inplace=True)
temp.replace('Veteran&39;s Administration',0,inplace=True)
X1=temp

temp=trainingData['BENEFITSSOURCECODE15298_NCI']
temp.replace('Food stamps or money for food or a benefits card', value=0,inplace=True)
temp.replace('MEDICAID Health Insurance Program (or local name)',1,inplace=True)
temp.replace('MEDICARE Health Insurance Program (or local name)',0,inplace=True)
temp.replace('Other Source',0,inplace=True)
temp.replace('Section 8,public housing,or other rental assistance',0,inplace=True)
temp.replace('Special Supplemental Nutrition Program for Women,Infants and Children (WIC)',0,inplace=True)
temp.replace('State Children&#39;s Health Insureance Program (or local name)',0,inplace=True)
temp.replace('TANF Child Care Services (or local name)',0,inplace=True)
temp.replace('TANF Transportation servies (or local name)',0,inplace=True)
temp.replace('Veteran&39;s Administration',0,inplace=True)
X2=temp

temp=trainingData['BENEFITSSOURCECODE15298_NCI']
temp.replace('Food stamps or money for food or a benefits card', value=0,inplace=True)
temp.replace('MEDICAID Health Insurance Program (or local name)',0,inplace=True)
temp.replace('MEDICARE Health Insurance Program (or local name)',1,inplace=True)
temp.replace('Other Source',0,inplace=True)
temp.replace('Section 8,public housing,or other rental assistance',0,inplace=True)
temp.replace('Special Supplemental Nutrition Program for Women,Infants and Children (WIC)',0,inplace=True)
temp.replace('State Children&#39;s Health Insureance Program (or local name)',0,inplace=True)
temp.replace('TANF Child Care Services (or local name)',0,inplace=True)
temp.replace('TANF Transportation servies (or local name)',0,inplace=True)
temp.replace('Veteran&39;s Administration',0,inplace=True)
X3=temp

temp=trainingData['BENEFITSSOURCECODE15298_NCI']
temp.replace('Food stamps or money for food or a benefits card', value=0,inplace=True)
temp.replace('MEDICAID Health Insurance Program (or local name)',0,inplace=True)
temp.replace('MEDICARE Health Insurance Program (or local name)',0,inplace=True)
temp.replace('Other Source',1,inplace=True)
temp.replace('Section 8,public housing,or other rental assistance',0,inplace=True)
temp.replace('Special Supplemental Nutrition Program for Women,Infants and Children (WIC)',0,inplace=True)
temp.replace('State Children&#39;s Health Insureance Program (or local name)',0,inplace=True)
temp.replace('TANF Child Care Services (or local name)',0,inplace=True)
temp.replace('TANF Transportation servies (or local name)',0,inplace=True)
temp.replace('Veteran&39;s Administration',0,inplace=True)
X4=temp

temp=trainingData['BENEFITSSOURCECODE15298_NCI']
temp.replace('Food stamps or money for food or a benefits card', value=0,inplace=True)
temp.replace('MEDICAID Health Insurance Program (or local name)',0,inplace=True)
temp.replace('MEDICARE Health Insurance Program (or local name)',0,inplace=True)
temp.replace('Other Source',0,inplace=True)
temp.replace('Section 8,public housing,or other rental assistance',1,inplace=True)
temp.replace('Special Supplemental Nutrition Program for Women,Infants and Children (WIC)',0,inplace=True)
temp.replace('State Children&#39;s Health Insureance Program (or local name)',0,inplace=True)
temp.replace('TANF Child Care Services (or local name)',0,inplace=True)
temp.replace('TANF Transportation servies (or local name)',0,inplace=True)
temp.replace('Veteran&39;s Administration',0,inplace=True)
X5=temp

temp=trainingData['BENEFITSSOURCECODE15298_NCI']
temp.replace('Food stamps or money for food or a benefits card', value=0,inplace=True)
temp.replace('MEDICAID Health Insurance Program (or local name)',0,inplace=True)
temp.replace('MEDICARE Health Insurance Program (or local name)',0,inplace=True)
temp.replace('Other Source',0,inplace=True)
temp.replace('Section 8,public housing,or other rental assistance',0,inplace=True)
temp.replace('Special Supplemental Nutrition Program for Women,Infants and Children (WIC)',1,inplace=True)
temp.replace('State Children&#39;s Health Insureance Program (or local name)',0,inplace=True)
temp.replace('TANF Child Care Services (or local name)',0,inplace=True)
temp.replace('TANF Transportation servies (or local name)',0,inplace=True)
temp.replace('Veteran&39;s Administration',0,inplace=True)
X6=temp

temp=trainingData['BENEFITSSOURCECODE15298_NCI']
temp.replace('Food stamps or money for food or a benefits card', value=0,inplace=True)
temp.replace('MEDICAID Health Insurance Program (or local name)',0,inplace=True)
temp.replace('MEDICARE Health Insurance Program (or local name)',0,inplace=True)
temp.replace('Other Source',0,inplace=True)
temp.replace('Section 8,public housing,or other rental assistance',0,inplace=True)
temp.replace('Special Supplemental Nutrition Program for Women,Infants and Children (WIC)',0,inplace=True)
temp.replace('State Children&#39;s Health Insureance Program (or local name)',1,inplace=True)
temp.replace('TANF Child Care Services (or local name)',0,inplace=True)
temp.replace('TANF Transportation servies (or local name)',0,inplace=True)
temp.replace('Veteran&39;s Administration',0,inplace=True)
X7=temp

temp=trainingData['BENEFITSSOURCECODE15298_NCI']
temp.replace('Food stamps or money for food or a benefits card', value=0,inplace=True)
temp.replace('MEDICAID Health Insurance Program (or local name)',0,inplace=True)
temp.replace('MEDICARE Health Insurance Program (or local name)',0,inplace=True)
temp.replace('Other Source',0,inplace=True)
temp.replace('Section 8,public housing,or other rental assistance',0,inplace=True)
temp.replace('Special Supplemental Nutrition Program for Women,Infants and Children (WIC)',0,inplace=True)
temp.replace('State Children&#39;s Health Insureance Program (or local name)',0,inplace=True)
temp.replace('TANF Child Care Services (or local name)',1,inplace=True)
temp.replace('TANF Transportation servies (or local name)',0,inplace=True)
temp.replace('Veteran&39;s Administration',0,inplace=True)
X8=temp

temp=trainingData['BENEFITSSOURCECODE15298_NCI']
temp.replace('Food stamps or money for food or a benefits card', value=0,inplace=True)
temp.replace('MEDICAID Health Insurance Program (or local name)',0,inplace=True)
temp.replace('MEDICARE Health Insurance Program (or local name)',0,inplace=True)
temp.replace('Other Source',0,inplace=True)
temp.replace('Section 8,public housing,or other rental assistance',0,inplace=True)
temp.replace('Special Supplemental Nutrition Program for Women,Infants and Children (WIC)',0,inplace=True)
temp.replace('State Children&#39;s Health Insureance Program (or local name)',0,inplace=True)
temp.replace('TANF Child Care Services (or local name)',0,inplace=True)
temp.replace('TANF Transportation servies (or local name)',1,inplace=True)
temp.replace('Veteran&39;s Administration',0,inplace=True)
X9=temp

temp=trainingData['BENEFITSSOURCECODE15298_NCI']
temp.replace('Food stamps or money for food or a benefits card', value=0,inplace=True)
temp.replace('MEDICAID Health Insurance Program (or local name)',0,inplace=True)
temp.replace('MEDICARE Health Insurance Program (or local name)',0,inplace=True)
temp.replace('Other Source',0,inplace=True)
temp.replace('Section 8,public housing,or other rental assistance',0,inplace=True)
temp.replace('Special Supplemental Nutrition Program for Women,Infants and Children (WIC)',0,inplace=True)
temp.replace('State Children&#39;s Health Insureance Program (or local name)',0,inplace=True)
temp.replace('TANF Child Care Services (or local name)',0,inplace=True)
temp.replace('TANF Transportation servies (or local name)',0,inplace=True)
temp.replace('Veteran&39;s Administration',1,inplace=True)
X10=temp

#OTHERNONCASHSOURCE15300
temp = trainingData['OTHERNONCASHSOURCE15300']
temp.replace('190',value=1,inplace=True)
temp.replace('Community Development Corporation of Long Island pay 86/mo of rent',0,inplace=True)
Y1 = temp

temp = trainingData['OTHERNONCASHSOURCE15300']
temp.replace('190',value=0,inplace=True)
temp.replace('Community Development Corporation of Long Island pay 86/mo of rent',1,inplace=True)
Y2 = temp

#IS A 3RD PARTY INVOLVED_NCI
temp = trainingData['IS A 3RD PARTY INVOLVED_NCI']
temp.replace('Yes',value=1,inplace=True)
temp.replace('No',0,inplace=True)
Z1 = temp

temp = trainingData['IS A 3RD PARTY INVOLVED_NCI']
temp.replace('Yes',value=0,inplace=True)
temp.replace('No',1,inplace=True)
Z2 = temp

#CURRENTLYEMPLOYED15251_NCI
temp = trainingData['CURRENTLYEMPLOYED15251_NCI']
temp.replace('Yes',value=1,inplace=True)
temp.replace('No',0,inplace=True)
a1 = temp

temp = trainingData['CURRENTLYEMPLOYED15251_NCI']
temp.replace('Yes',value=0,inplace=True)
temp.replace('No',1,inplace=True)
a2 = temp

#EMPLOYMENT IS CONSIDERED_NCI
temp = trainingData['EMPLOYMENT IS CONSIDERED_NCI']
temp.replace('Full-time',value=1,inplace=True)
temp.replace('Part-time',0,inplace=True)
b1 = temp

temp = trainingData['EMPLOYMENT IS CONSIDERED_NCI']
temp.replace('Full-time',value=0,inplace=True)
temp.replace('Part-time',1,inplace=True)
b2 = temp

#EMPLOYMENTTENURE15253
temp = trainingData['EMPLOYMENTTENURE15253']
temp.replace('Permanant',value=1,inplace=True)
temp.replace('Seasonal',0,inplace=True)
temp.replace('Temporary',0,inplace=True)
c1 = temp

temp = trainingData['EMPLOYMENTTENURE15253']
temp.replace('Permanant',value=0,inplace=True)
temp.replace('Seasonal',1,inplace=True)
temp.replace('Temporary',0,inplace=True)
c2 = temp

temp = trainingData['EMPLOYMENTTENURE15253']
temp.replace('Permanant',value=0,inplace=True)
temp.replace('Seasonal',0,inplace=True)
temp.replace('Temporary',1,inplace=True)
c3 = temp

#LOOKINGFORWORK15254
temp = trainingData['LOOKINGFORWORK15254']
temp.replace('Yes',value=1,inplace=True)
temp.replace('No',0,inplace=True)
d1 = temp

temp = trainingData['LOOKINGFORWORK15254']
temp.replace('Yes',value=0,inplace=True)
temp.replace('No',1,inplace=True)
d2 = temp

#EDUCATIONALVOCATIONALTRAINING15256
temp = trainingData['EDUCATIONALVOCATIONALTRAINING15256']
temp.replace('Yes',value=1,inplace=True)
temp.replace('No',0,inplace=True)
e1 = temp

temp = trainingData['EDUCATIONALVOCATIONALTRAINING15256']
temp.replace('Yes',value=0,inplace=True)
temp.replace('No',1,inplace=True)
e2 = temp

#EDUCATIONALVOCATIONALTRAINING15256
temp = trainingData['EDUCATIONALVOCATIONALTRAINING15256']
temp.replace('Yes',value=1,inplace=True)
temp.replace('No',0,inplace=True)
f1 = temp

temp = trainingData['EDUCATIONALVOCATIONALTRAINING15256']
temp.replace('Yes',value=0,inplace=True)
temp.replace('No',1,inplace=True)
f2 = temp

#HIGHESTSCHOOLLEVEL15257_y
temp = trainingData['HIGHESTSCHOOLLEVEL15257_y']
temp.replace('10th grade',value=1,inplace=True)
temp.replace('11th grade',0,inplace=True)
temp.replace('12th grade, no diploma',0,inplace=True)
temp.replace('5th grade or 6th grade',0,inplace=True)
temp.replace('7th grade or 8th grade',0,inplace=True)
temp.replace('9th grade',0,inplace=True)
temp.replace('GED',0,inplace=True)
temp.replace('High school diploma',0,inplace=True)
temp.replace('No schooling completed',0,inplace=True)
temp.replace('Nursery school to 4th grade',0,inplace=True)
temp.replace('Post-secondary school',0,inplace=True)
g1 = temp

temp = trainingData['HIGHESTSCHOOLLEVEL15257_y']
temp.replace('10th grade',value=0,inplace=True)
temp.replace('11th grade',1,inplace=True)
temp.replace('12th grade, no diploma',0,inplace=True)
temp.replace('5th grade or 6th grade',0,inplace=True)
temp.replace('7th grade or 8th grade',0,inplace=True)
temp.replace('9th grade',0,inplace=True)
temp.replace('GED',0,inplace=True)
temp.replace('High school diploma',0,inplace=True)
temp.replace('No schooling completed',0,inplace=True)
temp.replace('Nursery school to 4th grade',0,inplace=True)
temp.replace('Post-secondary school',0,inplace=True)
g2 = temp

temp = trainingData['HIGHESTSCHOOLLEVEL15257_y']
temp.replace('10th grade',value=0,inplace=True)
temp.replace('11th grade',0,inplace=True)
temp.replace('12th grade, no diploma',1,inplace=True)
temp.replace('5th grade or 6th grade',0,inplace=True)
temp.replace('7th grade or 8th grade',0,inplace=True)
temp.replace('9th grade',0,inplace=True)
temp.replace('GED',0,inplace=True)
temp.replace('High school diploma',0,inplace=True)
temp.replace('No schooling completed',0,inplace=True)
temp.replace('Nursery school to 4th grade',0,inplace=True)
temp.replace('Post-secondary school',0,inplace=True)
g3 = temp

temp = trainingData['HIGHESTSCHOOLLEVEL15257_y']
temp.replace('10th grade',value=0,inplace=True)
temp.replace('11th grade',0,inplace=True)
temp.replace('12th grade, no diploma',0,inplace=True)
temp.replace('5th grade or 6th grade',1,inplace=True)
temp.replace('7th grade or 8th grade',0,inplace=True)
temp.replace('9th grade',0,inplace=True)
temp.replace('GED',0,inplace=True)
temp.replace('High school diploma',0,inplace=True)
temp.replace('No schooling completed',0,inplace=True)
temp.replace('Nursery school to 4th grade',0,inplace=True)
temp.replace('Post-secondary school',0,inplace=True)
g4 = temp

temp = trainingData['HIGHESTSCHOOLLEVEL15257_y']
temp.replace('10th grade',value=0,inplace=True)
temp.replace('11th grade',0,inplace=True)
temp.replace('12th grade, no diploma',0,inplace=True)
temp.replace('5th grade or 6th grade',0,inplace=True)
temp.replace('7th grade or 8th grade',1,inplace=True)
temp.replace('9th grade',0,inplace=True)
temp.replace('GED',0,inplace=True)
temp.replace('High school diploma',0,inplace=True)
temp.replace('No schooling completed',0,inplace=True)
temp.replace('Nursery school to 4th grade',0,inplace=True)
temp.replace('Post-secondary school',0,inplace=True)
g5 = temp

temp = trainingData['HIGHESTSCHOOLLEVEL15257_y']
temp.replace('10th grade',value=0,inplace=True)
temp.replace('11th grade',0,inplace=True)
temp.replace('12th grade, no diploma',0,inplace=True)
temp.replace('5th grade or 6th grade',0,inplace=True)
temp.replace('7th grade or 8th grade',0,inplace=True)
temp.replace('9th grade',1,inplace=True)
temp.replace('GED',0,inplace=True)
temp.replace('High school diploma',0,inplace=True)
temp.replace('No schooling completed',0,inplace=True)
temp.replace('Nursery school to 4th grade',0,inplace=True)
temp.replace('Post-secondary school',0,inplace=True)
g6 = temp

temp = trainingData['HIGHESTSCHOOLLEVEL15257_y']
temp.replace('10th grade',value=0,inplace=True)
temp.replace('11th grade',0,inplace=True)
temp.replace('12th grade, no diploma',0,inplace=True)
temp.replace('5th grade or 6th grade',0,inplace=True)
temp.replace('7th grade or 8th grade',0,inplace=True)
temp.replace('9th grade',0,inplace=True)
temp.replace('GED',1,inplace=True)
temp.replace('High school diploma',0,inplace=True)
temp.replace('No schooling completed',0,inplace=True)
temp.replace('Nursery school to 4th grade',0,inplace=True)
temp.replace('Post-secondary school',0,inplace=True)
g7 = temp

temp = trainingData['HIGHESTSCHOOLLEVEL15257_y']
temp.replace('10th grade',value=0,inplace=True)
temp.replace('11th grade',0,inplace=True)
temp.replace('12th grade, no diploma',0,inplace=True)
temp.replace('5th grade or 6th grade',0,inplace=True)
temp.replace('7th grade or 8th grade',0,inplace=True)
temp.replace('9th grade',0,inplace=True)
temp.replace('GED',0,inplace=True)
temp.replace('High school diploma',1,inplace=True)
temp.replace('No schooling completed',0,inplace=True)
temp.replace('Nursery school to 4th grade',0,inplace=True)
temp.replace('Post-secondary school',0,inplace=True)
g8 = temp

temp = trainingData['HIGHESTSCHOOLLEVEL15257_y']
temp.replace('10th grade',value=0,inplace=True)
temp.replace('11th grade',0,inplace=True)
temp.replace('12th grade, no diploma',0,inplace=True)
temp.replace('5th grade or 6th grade',0,inplace=True)
temp.replace('7th grade or 8th grade',0,inplace=True)
temp.replace('9th grade',0,inplace=True)
temp.replace('GED',0,inplace=True)
temp.replace('High school diploma',0,inplace=True)
temp.replace('No schooling completed',1,inplace=True)
temp.replace('Nursery school to 4th grade',0,inplace=True)
temp.replace('Post-secondary school',0,inplace=True)
g9 = temp

temp = trainingData['HIGHESTSCHOOLLEVEL15257_y']
temp.replace('10th grade',value=0,inplace=True)
temp.replace('11th grade',0,inplace=True)
temp.replace('12th grade, no diploma',0,inplace=True)
temp.replace('5th grade or 6th grade',0,inplace=True)
temp.replace('7th grade or 8th grade',0,inplace=True)
temp.replace('9th grade',0,inplace=True)
temp.replace('GED',0,inplace=True)
temp.replace('High school diploma',0,inplace=True)
temp.replace('No schooling completed',0,inplace=True)
temp.replace('Nursery school to 4th grade',1,inplace=True)
temp.replace('Post-secondary school',0,inplace=True)
g10 = temp

temp = trainingData['HIGHESTSCHOOLLEVEL15257_y']
temp.replace('10th grade',value=0,inplace=True)
temp.replace('11th grade',0,inplace=True)
temp.replace('12th grade, no diploma',0,inplace=True)
temp.replace('5th grade or 6th grade',0,inplace=True)
temp.replace('7th grade or 8th grade',0,inplace=True)
temp.replace('9th grade',0,inplace=True)
temp.replace('GED',0,inplace=True)
temp.replace('High school diploma',0,inplace=True)
temp.replace('No schooling completed',0,inplace=True)
temp.replace('Nursery school to 4th grade',0,inplace=True)
temp.replace('Post-secondary school',1,inplace=True)
g11 = temp

#DEGREECODE15258_NCI
temp = trainingData['DEGREECODE15258_NCI']
temp.replace('Associates Degree',value=1,inplace=True)
temp.replace('Bachelors',0,inplace=True)
temp.replace('Doctorate',0,inplace=True)
temp.replace('Masters',0,inplace=True)
temp.replace('None',0,inplace=True)
temp.replace('9th grade',0,inplace=True)
temp.replace('GED',0,inplace=True)
temp.replace('Other graduate/professional degree',0,inplace=True)
h1 = temp

temp = trainingData['DEGREECODE15258_NCI']
temp.replace('Associates Degree',value=0,inplace=True)
temp.replace('Bachelors',1,inplace=True)
temp.replace('Doctorate',0,inplace=True)
temp.replace('Masters',0,inplace=True)
temp.replace('None',0,inplace=True)
temp.replace('9th grade',0,inplace=True)
temp.replace('GED',0,inplace=True)
temp.replace('Other graduate/professional degree',0,inplace=True)
h2 = temp

temp = trainingData['DEGREECODE15258_NCI']
temp.replace('Associates Degree',value=0,inplace=True)
temp.replace('Bachelors',0,inplace=True)
temp.replace('Doctorate',1,inplace=True)
temp.replace('Masters',0,inplace=True)
temp.replace('None',0,inplace=True)
temp.replace('9th grade',0,inplace=True)
temp.replace('GED',0,inplace=True)
temp.replace('Other graduate/professional degree',0,inplace=True)
h3 = temp

temp = trainingData['DEGREECODE15258_NCI']
temp.replace('Associates Degree',value=0,inplace=True)
temp.replace('Bachelors',0,inplace=True)
temp.replace('Doctorate',0,inplace=True)
temp.replace('Masters',1,inplace=True)
temp.replace('None',0,inplace=True)
temp.replace('9th grade',0,inplace=True)
temp.replace('GED',0,inplace=True)
temp.replace('Other graduate/professional degree',0,inplace=True)
h4 = temp

temp = trainingData['DEGREECODE15258_NCI']
temp.replace('Associates Degree',value=0,inplace=True)
temp.replace('Bachelors',0,inplace=True)
temp.replace('Doctorate',0,inplace=True)
temp.replace('Masters',0,inplace=True)
temp.replace('None',1,inplace=True)
temp.replace('9th grade',0,inplace=True)
temp.replace('GED',0,inplace=True)
temp.replace('Other graduate/professional degree',0,inplace=True)
h5 = temp

temp = trainingData['DEGREECODE15258_NCI']
temp.replace('Associates Degree',value=0,inplace=True)
temp.replace('Bachelors',0,inplace=True)
temp.replace('Doctorate',0,inplace=True)
temp.replace('Masters',0,inplace=True)
temp.replace('None',0,inplace=True)
temp.replace('9th grade',1,inplace=True)
temp.replace('GED',0,inplace=True)
temp.replace('Other graduate/professional degree',0,inplace=True)
h6 = temp

temp = trainingData['DEGREECODE15258_NCI']
temp.replace('Associates Degree',value=0,inplace=True)
temp.replace('Bachelors',0,inplace=True)
temp.replace('Doctorate',0,inplace=True)
temp.replace('Masters',0,inplace=True)
temp.replace('None',0,inplace=True)
temp.replace('9th grade',0,inplace=True)
temp.replace('GED',1,inplace=True)
temp.replace('Other graduate/professional degree',0,inplace=True)
h7 = temp

temp = trainingData['DEGREECODE15258_NCI']
temp.replace('Associates Degree',value=0,inplace=True)
temp.replace('Bachelors',0,inplace=True)
temp.replace('Doctorate',0,inplace=True)
temp.replace('Masters',0,inplace=True)
temp.replace('None',0,inplace=True)
temp.replace('9th grade',0,inplace=True)
temp.replace('GED',0,inplace=True)
temp.replace('Other graduate/professional degree',1,inplace=True)
h8 = temp

#INCOMEBENEFITTYPE15279_NCI
temp = trainingData['INCOMEBENEFITTYPE15279_NCI']
temp.replace('Income',value=1,inplace=True)
temp.replace('Non-cash benefits',0,inplace=True)
i1 = temp

temp = trainingData['INCOMEBENEFITTYPE15279_NCI']
temp.replace('Income',value=0,inplace=True)
temp.replace('Non-cash benefits',1,inplace=True)
i2 = temp

#INCOMESOURCECODE15280_NCI
temp=trainingData['INCOMESOURCECODE15280_NCI']
temp.replace('Alimony or other spousal support',value=1,inplace=True)
temp.replace('Child Support',0,inplace=True)
temp.replace('Earned Income',0,inplace=True)
temp.replace('No financial resources',0,inplace=True)
temp.replace('Other Source',0,inplace=True)
temp.replace('Pension from a former job',0,inplace=True)
temp.replace('Private Disability Insurance',0,inplace=True)
temp.replace('Public Assistance',0,inplace=True)
temp.replace('Retirement Income from Social Security',0,inplace=True)
temp.replace('Social Security Disability Income (SSDI)',0,inplace=True)
temp.replace('Supplemental Security Insurance or SSI',0,inplace=True)
temp.replace('Unemployment Insurance',0,inplace=True)
temp.replace('Veteran&#39;s Disability',0,inplace=True)
temp.replace('Veteran&#39;s Pension',0,inplace=True)
temp.replace('Veteran&#39;s Compensation',0,inplace=True)
j1=temp

temp=trainingData['INCOMESOURCECODE15280_NCI']
temp.replace('Alimony or other spousal support',value=0,inplace=True)
temp.replace('Child Support',1,inplace=True)
temp.replace('Earned Income',0,inplace=True)
temp.replace('No financial resources',0,inplace=True)
temp.replace('Other Source',0,inplace=True)
temp.replace('Pension from a former job',0,inplace=True)
temp.replace('Private Disability Insurance',0,inplace=True)
temp.replace('Public Assistance',0,inplace=True)
temp.replace('Retirement Income from Social Security',0,inplace=True)
temp.replace('Social Security Disability Income (SSDI)',0,inplace=True)
temp.replace('Supplemental Security Insurance or SSI',0,inplace=True)
temp.replace('Unemployment Insurance',0,inplace=True)
temp.replace('Veteran&#39;s Disability',0,inplace=True)
temp.replace('Veteran&#39;s Pension',0,inplace=True)
temp.replace('Veteran&#39;s Compensation',0,inplace=True)
j2=temp

temp=trainingData['INCOMESOURCECODE15280_NCI']
temp.replace('Alimony or other spousal support',value=0,inplace=True)
temp.replace('Child Support',0,inplace=True)
temp.replace('Earned Income',3,inplace=True)
temp.replace('No financial resources',0,inplace=True)
temp.replace('Other Source',0,inplace=True)
temp.replace('Pension from a former job',0,inplace=True)
temp.replace('Private Disability Insurance',0,inplace=True)
temp.replace('Public Assistance',0,inplace=True)
temp.replace('Retirement Income from Social Security',0,inplace=True)
temp.replace('Social Security Disability Income (SSDI)',0,inplace=True)
temp.replace('Supplemental Security Insurance or SSI',0,inplace=True)
temp.replace('Unemployment Insurance',0,inplace=True)
temp.replace('Veteran&#39;s Disability',0,inplace=True)
temp.replace('Veteran&#39;s Pension',0,inplace=True)
temp.replace('Veteran&#39;s Compensation',0,inplace=True)
j3=temp

temp=trainingData['INCOMESOURCECODE15280_NCI']
temp.replace('Alimony or other spousal support',value=0,inplace=True)
temp.replace('Child Support',0,inplace=True)
temp.replace('Earned Income',0,inplace=True)
temp.replace('No financial resources',1,inplace=True)
temp.replace('Other Source',0,inplace=True)
temp.replace('Pension from a former job',0,inplace=True)
temp.replace('Private Disability Insurance',0,inplace=True)
temp.replace('Public Assistance',0,inplace=True)
temp.replace('Retirement Income from Social Security',0,inplace=True)
temp.replace('Social Security Disability Income (SSDI)',0,inplace=True)
temp.replace('Supplemental Security Insurance or SSI',0,inplace=True)
temp.replace('Unemployment Insurance',0,inplace=True)
temp.replace('Veteran&#39;s Disability',0,inplace=True)
temp.replace('Veteran&#39;s Pension',0,inplace=True)
temp.replace('Veteran&#39;s Compensation',0,inplace=True)
j4=temp

temp=trainingData['INCOMESOURCECODE15280_NCI']
temp.replace('Alimony or other spousal support',value=0,inplace=True)
temp.replace('Child Support',0,inplace=True)
temp.replace('Earned Income',0,inplace=True)
temp.replace('No financial resources',0,inplace=True)
temp.replace('Other Source',1,inplace=True)
temp.replace('Pension from a former job',0,inplace=True)
temp.replace('Private Disability Insurance',0,inplace=True)
temp.replace('Public Assistance',0,inplace=True)
temp.replace('Retirement Income from Social Security',0,inplace=True)
temp.replace('Social Security Disability Income (SSDI)',0,inplace=True)
temp.replace('Supplemental Security Insurance or SSI',0,inplace=True)
temp.replace('Unemployment Insurance',0,inplace=True)
temp.replace('Veteran&#39;s Disability',0,inplace=True)
temp.replace('Veteran&#39;s Pension',0,inplace=True)
temp.replace('Veteran&#39;s Compensation',0,inplace=True)
j5=temp

temp=trainingData['INCOMESOURCECODE15280_NCI']
temp.replace('Alimony or other spousal support',value=0,inplace=True)
temp.replace('Child Support',0,inplace=True)
temp.replace('Earned Income',0,inplace=True)
temp.replace('No financial resources',0,inplace=True)
temp.replace('Other Source',0,inplace=True)
temp.replace('Pension from a former job',1,inplace=True)
temp.replace('Private Disability Insurance',0,inplace=True)
temp.replace('Public Assistance',0,inplace=True)
temp.replace('Retirement Income from Social Security',0,inplace=True)
temp.replace('Social Security Disability Income (SSDI)',0,inplace=True)
temp.replace('Supplemental Security Insurance or SSI',0,inplace=True)
temp.replace('Unemployment Insurance',0,inplace=True)
temp.replace('Veteran&#39;s Disability',0,inplace=True)
temp.replace('Veteran&#39;s Pension',0,inplace=True)
temp.replace('Veteran&#39;s Compensation',0,inplace=True)
j6=temp

temp=trainingData['INCOMESOURCECODE15280_NCI']
temp.replace('Alimony or other spousal support',value=0,inplace=True)
temp.replace('Child Support',0,inplace=True)
temp.replace('Earned Income',0,inplace=True)
temp.replace('No financial resources',0,inplace=True)
temp.replace('Other Source',0,inplace=True)
temp.replace('Pension from a former job',0,inplace=True)
temp.replace('Private Disability Insurance',1,inplace=True)
temp.replace('Public Assistance',0,inplace=True)
temp.replace('Retirement Income from Social Security',0,inplace=True)
temp.replace('Social Security Disability Income (SSDI)',0,inplace=True)
temp.replace('Supplemental Security Insurance or SSI',0,inplace=True)
temp.replace('Unemployment Insurance',0,inplace=True)
temp.replace('Veteran&#39;s Disability',0,inplace=True)
temp.replace('Veteran&#39;s Pension',0,inplace=True)
temp.replace('Veteran&#39;s Compensation',0,inplace=True)
j7=temp

temp=trainingData['INCOMESOURCECODE15280_NCI']
temp.replace('Alimony or other spousal support',value=0,inplace=True)
temp.replace('Child Support',0,inplace=True)
temp.replace('Earned Income',0,inplace=True)
temp.replace('No financial resources',0,inplace=True)
temp.replace('Other Source',0,inplace=True)
temp.replace('Pension from a former job',0,inplace=True)
temp.replace('Private Disability Insurance',0,inplace=True)
temp.replace('Public Assistance',1,inplace=True)
temp.replace('Retirement Income from Social Security',0,inplace=True)
temp.replace('Social Security Disability Income (SSDI)',0,inplace=True)
temp.replace('Supplemental Security Insurance or SSI',0,inplace=True)
temp.replace('Unemployment Insurance',0,inplace=True)
temp.replace('Veteran&#39;s Disability',0,inplace=True)
temp.replace('Veteran&#39;s Pension',0,inplace=True)
temp.replace('Veteran&#39;s Compensation',0,inplace=True)
j8=temp

temp=trainingData['INCOMESOURCECODE15280_NCI']
temp.replace('Alimony or other spousal support',value=0,inplace=True)
temp.replace('Child Support',0,inplace=True)
temp.replace('Earned Income',0,inplace=True)
temp.replace('No financial resources',0,inplace=True)
temp.replace('Other Source',0,inplace=True)
temp.replace('Pension from a former job',0,inplace=True)
temp.replace('Private Disability Insurance',0,inplace=True)
temp.replace('Public Assistance',0,inplace=True)
temp.replace('Retirement Income from Social Security',1,inplace=True)
temp.replace('Social Security Disability Income (SSDI)',0,inplace=True)
temp.replace('Supplemental Security Insurance or SSI',0,inplace=True)
temp.replace('Unemployment Insurance',0,inplace=True)
temp.replace('Veteran&#39;s Disability',0,inplace=True)
temp.replace('Veteran&#39;s Pension',0,inplace=True)
temp.replace('Veteran&#39;s Compensation',0,inplace=True)
j9=temp

temp=trainingData['INCOMESOURCECODE15280_NCI']
temp.replace('Alimony or other spousal support',value=0,inplace=True)
temp.replace('Child Support',0,inplace=True)
temp.replace('Earned Income',0,inplace=True)
temp.replace('No financial resources',0,inplace=True)
temp.replace('Other Source',0,inplace=True)
temp.replace('Pension from a former job',0,inplace=True)
temp.replace('Private Disability Insurance',0,inplace=True)
temp.replace('Public Assistance',0,inplace=True)
temp.replace('Retirement Income from Social Security',0,inplace=True)
temp.replace('Social Security Disability Income (SSDI)',1,inplace=True)
temp.replace('Supplemental Security Insurance or SSI',0,inplace=True)
temp.replace('Unemployment Insurance',0,inplace=True)
temp.replace('Veteran&#39;s Disability',0,inplace=True)
temp.replace('Veteran&#39;s Pension',0,inplace=True)
temp.replace('Veteran&#39;s Compensation',0,inplace=True)
j10=temp

temp=trainingData['INCOMESOURCECODE15280_NCI']
temp.replace('Alimony or other spousal support',value=0,inplace=True)
temp.replace('Child Support',0,inplace=True)
temp.replace('Earned Income',0,inplace=True)
temp.replace('No financial resources',0,inplace=True)
temp.replace('Other Source',0,inplace=True)
temp.replace('Pension from a former job',0,inplace=True)
temp.replace('Private Disability Insurance',0,inplace=True)
temp.replace('Public Assistance',0,inplace=True)
temp.replace('Retirement Income from Social Security',0,inplace=True)
temp.replace('Social Security Disability Income (SSDI)',0,inplace=True)
temp.replace('Supplemental Security Insurance or SSI',1,inplace=True)
temp.replace('Unemployment Insurance',0,inplace=True)
temp.replace('Veteran&#39;s Disability',0,inplace=True)
temp.replace('Veteran&#39;s Pension',0,inplace=True)
temp.replace('Veteran&#39;s Compensation',0,inplace=True)
j11=temp

temp=trainingData['INCOMESOURCECODE15280_NCI']
temp.replace('Alimony or other spousal support',value=0,inplace=True)
temp.replace('Child Support',0,inplace=True)
temp.replace('Earned Income',0,inplace=True)
temp.replace('No financial resources',0,inplace=True)
temp.replace('Other Source',0,inplace=True)
temp.replace('Pension from a former job',0,inplace=True)
temp.replace('Private Disability Insurance',0,inplace=True)
temp.replace('Public Assistance',0,inplace=True)
temp.replace('Retirement Income from Social Security',0,inplace=True)
temp.replace('Social Security Disability Income (SSDI)',0,inplace=True)
temp.replace('Supplemental Security Insurance or SSI',0,inplace=True)
temp.replace('Unemployment Insurance',1,inplace=True)
temp.replace('Veteran&#39;s Disability',0,inplace=True)
temp.replace('Veteran&#39;s Pension',0,inplace=True)
temp.replace('Veteran&#39;s Compensation',0,inplace=True)
j12=temp

temp=trainingData['INCOMESOURCECODE15280_NCI']
temp.replace('Alimony or other spousal support',value=0,inplace=True)
temp.replace('Child Support',0,inplace=True)
temp.replace('Earned Income',0,inplace=True)
temp.replace('No financial resources',0,inplace=True)
temp.replace('Other Source',0,inplace=True)
temp.replace('Pension from a former job',0,inplace=True)
temp.replace('Private Disability Insurance',0,inplace=True)
temp.replace('Public Assistance',0,inplace=True)
temp.replace('Retirement Income from Social Security',0,inplace=True)
temp.replace('Social Security Disability Income (SSDI)',0,inplace=True)
temp.replace('Supplemental Security Insurance or SSI',0,inplace=True)
temp.replace('Unemployment Insurance',0,inplace=True)
temp.replace('Veteran&#39;s Disability',1,inplace=True)
temp.replace('Veteran&#39;s Pension',0,inplace=True)
temp.replace('Veteran&#39;s Compensation',0,inplace=True)
j13=temp

temp=trainingData['INCOMESOURCECODE15280_NCI']
temp.replace('Alimony or other spousal support',value=0,inplace=True)
temp.replace('Child Support',0,inplace=True)
temp.replace('Earned Income',0,inplace=True)
temp.replace('No financial resources',0,inplace=True)
temp.replace('Other Source',0,inplace=True)
temp.replace('Pension from a former job',0,inplace=True)
temp.replace('Private Disability Insurance',0,inplace=True)
temp.replace('Public Assistance',0,inplace=True)
temp.replace('Retirement Income from Social Security',0,inplace=True)
temp.replace('Social Security Disability Income (SSDI)',0,inplace=True)
temp.replace('Supplemental Security Insurance or SSI',0,inplace=True)
temp.replace('Unemployment Insurance',0,inplace=True)
temp.replace('Veteran&#39;s Disability',0,inplace=True)
temp.replace('Veteran&#39;s Pension',1,inplace=True)
temp.replace('Veteran&#39;s Compensation',0,inplace=True)
j14=temp

temp=trainingData['INCOMESOURCECODE15280_NCI']
temp.replace('Alimony or other spousal support',value=0,inplace=True)
temp.replace('Child Support',0,inplace=True)
temp.replace('Earned Income',0,inplace=True)
temp.replace('No financial resources',0,inplace=True)
temp.replace('Other Source',0,inplace=True)
temp.replace('Pension from a former job',0,inplace=True)
temp.replace('Private Disability Insurance',0,inplace=True)
temp.replace('Public Assistance',0,inplace=True)
temp.replace('Retirement Income from Social Security',0,inplace=True)
temp.replace('Social Security Disability Income (SSDI)',0,inplace=True)
temp.replace('Supplemental Security Insurance or SSI',0,inplace=True)
temp.replace('Unemployment Insurance',0,inplace=True)
temp.replace('Veteran&#39;s Disability',0,inplace=True)
temp.replace('Veteran&#39;s Pension',0,inplace=True)
temp.replace('Veteran&#39;s Compensation',1,inplace=True)
j15=temp

# %%
X = trainingData[['HOW MANY TIMES HOMELESS. LEAVE BLANK IF ZERO.',\
                  'NUMBER OF CHILDREN_NCI','AGES OF CHILDREN CHECK ALL THAT APPLY_NCI',\
                  'ADULTS IN FAMILY INCLUDE CLIENT_NCI','MONTHLY RENT_NCI',\
                  'ARREARS OWEDBACK RENT_NCI','FOODSTAMP15299_NCI',\
                  'EARNEDINCOME15281_NCI','UNEMPLOYMENTINSURANCE15282_NCI','PA15289_NCI',\
                  'SSRETIREMENT15290_NCI','SSI15283_NCI','SSDI15284_NCI','VETERANDISABILITY15285_NCI',\
                  'PRIVATEDISABILITYINSURANCE15286_NCI','VETERANPENSION15291_NCI','JOBPENSION15292_NCI',\
                  'WORKERCOMPENSATION15287_NCI','TANF15288_NCI','CHILDSUPPORT15293_NCI','ALIMONY15294_NCI',\
                  'OTHERINCOMESOURCE15295_NCI','OTHERSOURCEAMOUNT15296_NCI','TOTALMONTHLYINCOME15297_NCI']]


Y = trainingData['PROGRAM']
Y.replace('Eviction Prevention Follow Up',value=1,inplace=True)
Y.replace('NaN',0,inplace=True)
Y = Y.as_matrix()

#make individual numpy vectors for each possible case for a category
X1 = np.stack((A1,A2,B1,B2,C1,C2,C3,C4,C5,C6,C7,C8,D1,D2,E1,E2,E3,E4,E5,E6,E7,E8,E9,F1,F2,G1,G2,G3,G4,G5,G6,G7,G8,G9,G10,G11,G12,G13,G14,H1,H2,H3,H4,H5,H6,I1,I2,I3,I4,I5,I6,I7,J1,J2,J3,J4,J5,J6,K1,K2,K3,K4,L1,L2,M1,M2,N1,N2,O1,O2,P1,P2,P3,Q1,Q2,R1,R2,S1,S2,T1,T2,U1,U2,V1,V1,v1,v2,W1,W2,W3,W4,W5,W6,W7,W8,W9,W10,W11,X1,X2,X3,X4,X5,X6,X7,X8,X9,X10,Y1,Y2,Z1,Z2,a1,a2,b1,b2,c1,c2,c3,d1,d2,e1,e2,f1,f2,g1,g2,g3,g4,g5,g6,g7,g8,g9,g10,g11,h1,h2,h3,h4,h5,h6,h7,h8,i1,i2,j1,j2,j3,j4,j5,j6,j7,j8,j9,j10,j11,j12,j13,j14,j15),axis=1)
X = np.concatenate((X,X1),axis=1)

print(np.shape(X))
imp = Imputer(missing_values='NaN', strategy='mean', axis=0)
imp.fit(X)
X = imp.transform(X)
X = robust_scale(X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-77c5d47f5192> in <module>()
#       4 Y.replace('',0,inplace=True)
#       5 Y = Y.as_matrix()
# ----> 6 X1 = np.stack((A1,A2,B1,B2,C1,C2,C3,C4,C5,C6,C7,C8,D1,D2,E1,E2,E3,E4,E5,E6,E7,E8,E9,F1,F2,G1,G2,G3,G4,G5,G6,G7,G8,G9,G10,G11,G12,G13,G14,H1,H2,H3,H4,H5,H6,I1,I2,I3,I4,I5,I6,I7,J1,J2,J3,J4,J5,J6,K1,K2,K3,K4,L1,L2,M1,M2,N1,N2,O1,O2,P1,P2,P3,Q1,Q2,R1,R2,S1,S2,T1,T2,U1,U2,V1,V1,v1,v2,W1,W2,W3,W4,W5,W6,W7,W8,W9,W10,W11,X1,X2,X3,X4,X5,X6,X7,X8,X9,X10,Y1,Y2,Z1,Z2,a1,a2,b1,b2,c1,c2,c3,d1,d2,e1,e2,f1,f2,g1,g2,g3,g4,g5,g6,g7,g8,g9,g10,g11,h1,h2,h3,h4,h5,h6,h7,h8,i1,i2,j1,j2,j3,j4,j5,j6,j7,j8,j9,j10,j11,j12,j13,j14,j15),axis=1)
#       7 X = np.concatenate((X,X1),axis=1)
#       8 print(np.shape(X))
#
# /Users/marydwyer/anaconda/lib/python3.6/site-packages/numpy/core/shape_base.py in stack(arrays, axis)
# ...
